# %%
"""
# Preprocessing Experiments

## 1. Import modules
```python
from src.preprocessing.arabic_cleaner import clean_arabic_text
from src.preprocessing.tokenizer import tokenize_arabic
```

## 2. Test cleaning
```python
sample_text = df['tweet'].iloc[0]
cleaned = clean_arabic_text(sample_text)
print("Original:", sample_text)
print("Cleaned:", cleaned)
```

## 3. Tokenization
```python
# Test tokenization on sample
```
"""
